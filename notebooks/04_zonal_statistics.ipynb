# %% [markdown]
# ### District level zonal stats for each year and indices
#
# Output:
# - district_statistics.csv

# %%
from src.zonal import *
from src.config import ROOT

# %%
DISTRICTS = (
    ROOT
    / "data"
    / "processed"
    / "study_districts.gpkg"
)

# %%
YEARS = [2016, 2022, 2025]

INDICES = [
    "NDVI",
    "NDWI",
    "NDBI",
]

table = batch_zonal_statistics(
    ROOT / "data" / "processed" / "indices",
    DISTRICTS,
    ROOT / "data" / "results" / "csv" / "district_statistics.csv",
    YEARS,
    INDICES,
    district_column="DISTRICT",
)
# Out:
# Processing 2016
#   NDVI
#   NDWI
#   NDBI
#
# Processing 2022
#   NDVI
#   NDWI
#   NDBI
#
# Processing 2025
#   NDVI
#   NDWI
#   NDBI
